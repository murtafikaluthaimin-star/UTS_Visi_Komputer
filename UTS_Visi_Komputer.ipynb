# %% [markdown]
# <a href="https://colab.research.google.com/github/murtafikaluthaimin-star/UTS_Visi_Komputer/blob/main/UTS_Visi_Komputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================
# 1. Import Library
# ================================
# !pip install opencv-python matplotlib

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# ================================
# 2. Upload Gambar
# ================================
uploaded = files.upload()

# ambil nama file yang diupload
file_name = list(uploaded.keys())[0]

# ================================
# 3. Baca Gambar
# ================================
img = cv2.imread(file_name)
img = cv2.resize(img, (300,300))

# ================================
# 4. Konversi ke HSV
# ================================
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# ================================
# 5. Segmentasi (Mask)
# ================================
mask = cv2.inRange(hsv, (0,50,50), (180,255,255))

# ================================
# 6. Morphology (Bersihkan Noise)
# ================================
kernel = np.ones((5,5), np.uint8)
hasil = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

# ================================
# 7. Tampilkan Hasil
# ================================
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Gambar Asli")

plt.subplot(1,3,2)
plt.imshow(mask, cmap='gray')
plt.title("Mask HSV")

plt.subplot(1,3,3)
plt.imshow(hasil, cmap='gray')
plt.title("Hasil Morfologi")

plt.show()
# Out:
# ...
#      <input type="file" id="files-89a47417-f51a-4504-b7b5-1bd8c805c6c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89a47417-f51a-4504-b7b5-1bd8c805c6c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ================================
# 1. Import Library
# ================================
# !pip install opencv-python matplotlib

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# ================================
# 2. Upload Gambar
# ================================
uploaded = files.upload()

# ambil nama file yang diupload
file_name = list(uploaded.keys())[0]

# ================================
# 3. Baca Gambar
# ================================
img = cv2.imread(file_name)
img = cv2.resize(img, (300,300))

# ================================
# 4. Konversi ke HSV
# ================================
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# ================================
# 5. Segmentasi (Mask)
# ================================
mask = cv2.inRange(hsv, (0,50,50), (180,255,255))

# ================================
# 6. Morphology (Bersihkan Noise)
# ================================
kernel = np.ones((5,5), np.uint8)
hasil = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

# ================================
# 7. Tampilkan Hasil
# ================================
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Gambar Asli")

plt.subplot(1,3,2)
plt.imshow(mask, cmap='gray')
plt.title("Mask HSV")

plt.subplot(1,3,3)
plt.imshow(hasil, cmap='gray')
plt.title("Hasil Morfologi")

plt.show()
# Out:
# ...
#      <input type="file" id="files-d1349f69-d502-4a4d-affe-b95ac692862a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1349f69-d502-4a4d-affe-b95ac692862a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ================================
# 1. Import Library
# ================================
# !pip install opencv-python matplotlib

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# ================================
# 2. Upload Gambar
# ================================
uploaded = files.upload()

# ambil nama file yang diupload
file_name = list(uploaded.keys())[0]

# ================================
# 3. Baca Gambar
# ================================
img = cv2.imread(file_name)
img = cv2.resize(img, (300,300))

# ================================
# 4. Konversi ke HSV
# ================================
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# ================================
# 5. Segmentasi (Mask)
# ================================
mask = cv2.inRange(hsv, (0,50,50), (180,255,255))

# ================================
# 6. Morphology (Bersihkan Noise)
# ================================
kernel = np.ones((5,5), np.uint8)
hasil = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

# ================================
# 7. Tampilkan Hasil
# ================================
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Gambar Asli")

plt.subplot(1,3,2)
plt.imshow(mask, cmap='gray')
plt.title("Mask HSV")

plt.subplot(1,3,3)
plt.imshow(hasil, cmap='gray')
plt.title("Hasil Morfologi")

plt.show()
# Out:
# ...
#      <input type="file" id="files-5b4f38da-f0bc-47c4-b974-2d4a0f20afb6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b4f38da-f0bc-47c4-b974-2d4a0f20afb6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
