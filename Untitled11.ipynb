# %% [markdown]
# <a href="https://colab.research.google.com/github/murtafikaluthaimin-star/UTS_Visi_Komputer/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# Membaca gambar
image = cv2.imread('great-white-shark-jaws-open-260nw-2722549823.jpg')

# %%
# Konversi ke grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Blur untuk mengurangi noise
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
# Deteksi tepi dengan Canny
edges = cv2.Canny(blur, 100, 200)

# %%
from google.colab.patches import cv2_imshow

# Menampilkan hasil
cv2_imshow(image)
cv2_imshow(edges)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=466x280>
# <PIL.Image.Image image mode=L size=466x280>

# %%
import cv2
import numpy as np

# Membaca gambar
image = cv2.imread('great-white-shark-jaws-open-260nw-2722549823.jpg')

# Resize opsional
image = cv2.resize(image, (600, 400))

# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Gaussian Blur
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
# =========================
# 1. SOBEL
# =========================
sobel_x = cv2.Sobel(blur, cv2.CV_64F, 1, 0, ksize=3)
sobel_y = cv2.Sobel(blur, cv2.CV_64F, 0, 1, ksize=3)

sobel = cv2.magnitude(sobel_x, sobel_y)
sobel = np.uint8(sobel)
# =========================
# 2. LAPLACIAN
# =========================
laplacian = cv2.Laplacian(blur, cv2.CV_64F)
laplacian = np.uint8(np.absolute(laplacian))

# %%
# =========================
# 3. CANNY
# =========================
canny = cv2.Canny(blur, 100, 200)

# %%
# =========================
# MENAMPILKAN HASIL
# =========================
cv2_imshow(image)
cv2_imshow(sobel)
cv2_imshow(laplacian)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>
# <PIL.Image.Image image mode=L size=600x400>
# <PIL.Image.Image image mode=L size=600x400>
# <PIL.Image.Image image mode=L size=600x400>
